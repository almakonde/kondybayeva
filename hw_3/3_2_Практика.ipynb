# %% [markdown]
# **Навигация по уроку**
#
# 1. [Условия и циклы.  Списки, словари, кортежи, множества](https://colab.research.google.com/drive/1DFtKZbd2GjOsVRNViq_p9gCo9kNDTDpD#scrollTo=UWRmGWmyGHbN)
# 2. Практика
# 3. [Домашняя работа](https://colab.research.google.com/drive/10O5HRkBdv5K4v4-jZ_0XQUveu7OwCrTB)

# %% [markdown]
# Практическая часть данного урока, содержит разбор простых задач, если вы чувствуете свою силу и считаете, что такие задачи вы можете решать без подсказок, то пропустите разбор и попробуйте решить самостоятельно. Если пока не можете, то внимательно проанализируйте решения задач и обратите внимание на все комментарии.

# %% [markdown]
# ## Упражнение 1. Играем в рулетку

# %% [markdown]
# **Условие.** На игровой рулетке в казино 38 выемок для шарика: 18 красных, столько же черных и две зеленые, пронумерованные 0 и 00 соответственно. Красные числа на рулетке: 1, 3, 5, 7, 9, 12, 14, 16, 18, 19, 21, 23, 25, 27, 30 32, 34
# и 36. Остальные номера в диапазоне положительных чисел до 36 – черные.
# Игрок может сделать самые разные ставки.
# Мы в данном упражнении будем рассматривать лишь следующие виды ставок:
# * одно число (от одного до 36, а также 0 или 00);
# * красное или черное;
# * четное или нечетное (заметьте, что номера 0 и 00 не являются ни четными, ни нечетными);
# * от 1 до 18 против от 19 до 36.
#
# Напишите программу, имитирующую игру на рулетке при помощи генератора случайных чисел в Python. После запуска рулетки выведите на экран выпавший номер и все сыгравшие ставки.
#
# Например, при выпадении номера 13 на экране должна появиться следующая последовательность строк:
#
# ```
# Выпавший номер: 13…
# Выигравшая ставка: 13
# Выигравшая ставка: черное
# Выигравшая ставка: нечетное
# Выигравшая ставка: от 1 до 18
# ```
#
# Если на рулетке выпал номер 0, вывод должен быть следующим:
# ```
# Выпавший номер: 0…
# Выигравшая ставка: 0
#
# ```
#
# Для номера 00 сообщения будут иметь следующий вид:
# ```
# Выпавший номер: 00…
# Выигравшая ставка: 00
# ```

# %%
# Попробуйте решить сами

# %%
#@title Решение
##
# Определяем выпавший номер на рулетке и выигрыш
#

from random import randrange

# Симулируем запуск рулетки, генерируем случайное число в диапазоне от 0 до 37 включительно
value = randrange(0, 38)

# используя число 37 для представления номера 00
if value == 37:
    print("Выпавший номер: 00...")
else:
    print("Выпавший номер: %d" % value)

# Отображаем выигрыш для одного числа
if value == 37:
    print("Выигравшая ставка: 00")
else:
    print("Выигравшая ставка:", value)

# Отображаем выигрыш по цветам
# В первой строке проверяем число на вхождение в ряд 1, 3, 5, 7 и 9
# Во второй строке проверяем число на вхождение в ряд 12, 14, 16 и 18
# В третьей строке проверяем число на вхождение в ряд 19, 21, 23, 25 и 27
# В четвертой строке проверяем число на вхождение в ряд 30, 32, 34 и 36
if value % 2 == 1 and value >= 1 and value <= 9 or \
   value % 2 == 0 and value >= 12 and value <= 18 or \
   value % 2 == 1 and value >= 19 and value <= 27 or \
   value % 2 == 0 and value >= 30 and value <= 36:
    print("Выигравшая ставка: красное")
elif value == 0 or value == 37:
    pass # ключевое слово, которое ничего не делает
else:
    print("Выигравшая ставка: черное")

# Отображаем выигрыш по чет/нечет
if value >= 1 and value <= 36:
    if value % 2 == 1:
        print("Выигравшая ставка: нечетное")
    else:
        print("Выигравшая ставка: четное")
# Отображаем выигрыш по низ/верх
if value >= 1 and value <= 18:
    print("Выигравшая ставка: от 1 до 18")
elif value >= 19 and value <= 36:
    print("Выигравшая ставка: от 19 до 36")
# Out:
# Выпавший номер: 23
# Выигравшая ставка: 23
# Выигравшая ставка: красное
# Выигравшая ставка: нечетное
# Выигравшая ставка: от 19 до 36

# %% [markdown]
# ## Упражнение 2. Билеты в зоопарк

# %% [markdown]
# **Условие.** В зоопарке цена входного билета зависит от возраста посетителя. Дети доmдвух лет допускаются бесплатно. Дети в возрасте от трех до 12 лет могут посещать зоопарк за 140. Пенсионерам старше 65 лет вход обойдется в 180, а обычный взрослый билет стоит 230.
# Напишите программу, которая будет запрашивать возраст всех посетителей в группе (по одному за раз) и выводить общую цену билетов для посещения зоопарка этой группой. В качестве индикатора окончания ввода можно по традиции использовать пустую строку. Общую цену билетов стоит выводить в формате с двумя знаками после запятой.

# %%
# Попробуйте решить сами

# %%
#@title Решение

##
# Рассчитать стоимость посещения зоопарка для группы
#
# Константы для хранения цен на разные категории билетов
BABY_PRICE = 0.00
CHILD_PRICE = 140
ADULT_PRICE = 230
SENIOR_PRICE = 180

# Сохраним как константы возрастные ограничения
BABY_LIMIT = 2
CHILD_LIMIT = 12
ADULT_LIMIT = 64

# Переменная для хранения общей суммы посещения
total = 0
# Читаем ввод пользователя до пустой строки
line = input("Введите возраст посетителя (пустая строка для окончания ввода): ")
while line != "":
    age = int(line)
    # Добавляем цену билета к общей сумме
    if age <= BABY_LIMIT:
        total = total + BABY_PRICE
    elif age <= CHILD_LIMIT:
        total = total + CHILD_PRICE
    elif age <= ADULT_LIMIT:
       total = total + ADULT_PRICE
    else:
       total = total + SENIOR_PRICE
    # Считываем возраст следующего посетителя
    line = input("Введите возраст посетителя (пустая строка для окончания ввода): ")

# Отображаем сумму группового посещения с правильным форматированием
print("Сумма посещения зоопарка для этой группы составит %.2f рублей" % total)
# Out:
# Введите возраст посетителя (пустая строка для окончания ввода): 59
# Введите возраст посетителя (пустая строка для окончания ввода): 32
# Введите возраст посетителя (пустая строка для окончания ввода): 12
# Введите возраст посетителя (пустая строка для окончания ввода): 16
# Введите возраст посетителя (пустая строка для окончания ввода): 8
# Введите возраст посетителя (пустая строка для окончания ввода):
# Сумма посещения зоопарка для этой группы составит 970.00 рублей

# %% [markdown]
# ## Упражнение 3. Код Цезаря

# %% [markdown]
# **Условие.** Одним из первых в истории примеров шифрования считаются закодированные послания Юлия Цезаря. Римскому полководцу необходимо было
# посылать письменные приказы своим генералам, но он не желал, чтобы в случае чего их прочитали недруги. В результате он стал шифровать свои
# послания довольно простым методом, который впоследствии стали называть кодом Цезаря.
# Идея шифрования была совершенно тривиальной и заключалась в циклическом сдвиге букв на три позиции. В итоге буква A превращалась в D,
# B – в E, C – в F и т. д. Последние три буквы алфавита переносились на начало. Таким образом, буква X становилась A, Y – B, а Z – C. Цифры и другие символы не подвергались шифрованию.
# Напишите программу, реализующую код Цезаря. Позвольте пользователю ввести фразу и количество символов для сдвига, после чего выведите
# результирующее сообщение. Убедитесь в том, что ваша программа шифрует как строчные, так и прописные буквы. Также должна быть возможность указывать отрицательный сдвиг, чтобы можно было использовать вашу программу для расшифровки фраз.
#
# Так как Цезарь не знал кириллицы, то буквы на кириллице возвращаем без изменения!

# %% [markdown]
# **Подсказка**
#
# Успользуйте функцию **ord**.
#
# Функция *ord* преобразует символ в целочисленную позицию в таблице ASCII. Функция chr возвращает символ в таблице ASCII по позиции, переданной в качестве аргумента.

# %%
# Попробуйте решить сами

# %%
#@title Решение

##
# Реализовать код Цезаря, в котором используются символы, сдвинутые
# на определенное количество позиций.
# Отрицательные значения сдвига можно использовать для декодирования.
#

# Запрашиваем у пользователя сообщение и сдвиг
message = input("Введите сообщение: ")
shift = int(input("Введите сдвиг: "))

# Обрабатываем каждый символ для создания зашифрованного сообщения
new_message = ""
for ch in message:
    if ch >= "a" and ch <= "z":
        # Обрабатываем букву в нижнем регистре, определяя ее позицию
        # в алфавите (0–25), вычисляя новую позицию и добавляя букву в сообщение
        pos = ord(ch) - ord("a")
        pos = (pos + shift) % 26
        new_char = chr(pos + ord("a"))
        new_message = new_message + new_char

    elif ch >= "A" and ch <= "Z":
        # Обрабатываем букву в верхнем регистре, определяя ее позицию
        # в алфавите (0–25), вычисляя новую позицию и добавляя букву в сообщение
        pos = ord(ch) - ord("A")
        pos = (pos + shift) % 26
        new_char = chr(pos + ord("A"))
        new_message = new_message + new_char
    else:
        # Если это не буква, просто сохраняем ее в сообщении
        new_message = new_message + ch

# Отображаем полученное сообщение
print("Новое сообщение", new_message)
# Out:
# Введите сообщение: hello!
# Введите сдвиг: 5
# Новое сообщение mjqqt!

# %% [markdown]
# ## Упражнение 4. Десятичное число в двоичное

# %% [markdown]
# **Условие.** Напишите программу, которая будет преобразовывать десятичные значения (по основанию 10) в двоичные (по основанию 2). Запросите целое
# число у  пользователя и,  следуя алгоритму, приведенному ниже, преобразуйте его в двоичную запись.
#
# ```
# Повторять
#  Переменной r присвоить остаток от деления q на 2
#  Преобразовать r в строку и добавить ее в начало переменной result
#  Разделить q на 2 с отбрасыванием остатка и присвоить полученное значение переменной q
# Пока q не станет равно нулю
# ```

# %%
# Попробуйте решить сами

# %%
#@title Решение

##
# Перевести десятичное число в двоичное
#
NEW_BASE = 2

# Запрашиваем число для перевода у пользователя
num = int(input("Введите неотрицательное целое число: "))

# Будем сохранять результат в переменной result
result = ""
q = num

# Пишем копию тела цикла вне самого цикла
r = q % NEW_BASE
result = str(r) + result
q = q // NEW_BASE

# Выполняем цикл, пока q не станет равен нулю
while q > 0:
    r = q % NEW_BASE
    result = str(r) + result
    q = q // NEW_BASE

# Отображаем результат
print(num, "в десятичной системе равно", result, "в двоичной.")
# Out:
# Введите неотрицательное целое число: 78
# 78 в десятичной системе равно 1001110 в двоичной.

# %% [markdown]
# ## Упражнение 5. Порядок сортировки

# %% [markdown]
# **Условие.** Напишите программу, которая будет запрашивать у пользователя целочисленные значения и сохранять их в виде списка. Индикатором окончания ввода значений должен служить ноль. Затем программа должна вывести на экран все введенные пользователем числа (кроме нуля) в порядке возрастания – по одному значению в строке. Используйте для сортировки либо метод sort.

# %%
# Попробуйте решить сами

# %%
#@title Решение
##
# Выводим числа, введенные пользователем, в порядке возрастания
#
# Начинаем с пустого списка
data = []

# Считываем значения и добавляем их в список, пока пользователь не введет ноль
num = int(input("Введите целое число (0 для окончания ввода): "))

while num != 0:
    data.append(num)
    num = int(input("Введите целое число (0 для окончания ввода): "))

# Сортируем значения
data.sort()

# Выводим числа в порядке возрастания
print("Введенные числа в порядке возрастания:")
for num in data:
 print(num)
# Out:
# Введите целое число (0 для окончания ввода): 4
# Введите целое число (0 для окончания ввода): 1
# Введите целое число (0 для окончания ввода): 9
# Введите целое число (0 для окончания ввода): 0
# Введенные числа в порядке возрастания:
# 1
# 4
# 9

# %% [markdown]
# ## Упражнение 6. Случайные лотерейные номера

# %% [markdown]
# **Условие.** Для выигрыша главного приза необходимо, чтобы шесть номеров на лотерейном билете совпали с шестью числами, выпавшими случайным образом в диапазоне от 1 до 49 во время очередного тиража. Напишите программу, которая будет случайным образом подбирать шесть номеров для вашего билета. Убедитесь в том, что среди этих чисел не будет дубликатов. Выведите номера билетов на экран по возрастанию.

# %%
# Попробуйте решить сами

# %%
#@title Решение
##
# Собираем уникальные случайные номера для лотерейного билета
#
from random import randrange
MIN_NUM = 1
MAX_NUM = 49
NUM_NUMS = 6

# Используем список для хранения номеров лотерейного билета
ticket_nums = []
# Генерируем NUM_NUMS случайных, но уникальных значений
for i in range(NUM_NUMS):
    # Генерируем номер, которого еще нет в списке
    rand = randrange(MIN_NUM, MAX_NUM + 1)

    # Будем перегенерировать число, пока оно есть в списке
    while rand in ticket_nums:
        rand = randrange(MIN_NUM, MAX_NUM + 1)

    # Добавляем номер к билету
    ticket_nums.append(rand)

# Сортируем номера по возрастанию и отображаем их
ticket_nums.sort()
print("Номера вашего билета: ", end="")
for n in ticket_nums:
    print(n, end=" ")
# Out:
# Номера вашего билета: 2 6 7 9 31 37

# %%
#@title Решение (более элегантное с применением множеств)
##
# Собираем уникальные случайные номера для лотерейного билета
#
from random import randrange
MIN_NUM = 1
MAX_NUM = 49
NUM_NUMS = 6

# Используем список для хранения номеров лотерейного билета
ticket_nums = set()
# Генерируем NUM_NUMS случайных, но уникальных значений
while len(ticket_nums) < i :

    # Генерируем номер, которого еще нет в списке
    ticket_nums.add(randrange(MIN_NUM, MAX_NUM + 1))

# Сортируем номера по возрастанию и отображаем их
ticket_nums = sorted(ticket_nums)

print("Номера вашего билета: ", end="")
for n in ticket_nums:
    print(n, end=" ")
# Out:
# Номера вашего билета: 4 12 14 17 32

# %% [markdown]
# ## Упражнение 7. Уникальные символы

# %% [markdown]
# **Условие.** Напишите программу, определяющую и выводящую на экран количество
# уникальных символов во введенной пользователем строке. Например, в строке Hello, World! содержится десять уникальных символов, а в строке zzz – один. Используйте словарь для решения этой задачи.

# %%
# Попробуйте решить сами

# %%
#@title Решение
##
# Считаем уникальные символы в строке при помощи словаря
#
# Запрашиваем строку у пользователя
s = input("Введите строку: ")

# Добавляем каждый символ в словарь со значением True. После окончания процедуры
# количество ключей в словаре и будет отражать число уникальных символов
characters = {}
for ch in s:
    characters[ch] = True


# Отображаем результат
print("Строка содержит", len(characters), "уникальных символов.")
# Out:
# Введите строку: Привет, мир!
# Строка содержит 10 уникальных символов.

# %% [markdown]
# На этом практическая часть урока завершена. Пора переходить к [домашей работе](https://colab.research.google.com/drive/10O5HRkBdv5K4v4-jZ_0XQUveu7OwCrTB#scrollTo=zOeMYvivGMl7).
